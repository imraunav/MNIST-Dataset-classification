# %%
import cv2

# %%
img = cv2.imread("/Users/raunavghosh/Downloads/RAUNAV 2/processed_P01X010-2022120600154.dump_high.png", cv2.IMREAD_ANYDEPTH)

# %%
img.dtype
# Out:
# dtype('uint16')

# %%
from matplotlib import pyplot as plt 
plt.imshow(img, cmap="gray")
